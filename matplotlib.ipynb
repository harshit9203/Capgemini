# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Matplotlib is used because it :-

# 1. requires less code
# 2. is simple and fast
# 3. autmatically creates figures and axes
# is perfect for learning, exams, and quick analysis

# %%
from matplotlib.legend import Legend

# num = np.arange(1,11)
# sq = num**2
# cub = num**3

# plt.figure(figsize=(10,10))

# plt.title('linechart')
# fontsize, color

# plt.plot(num, sq, marker='o', markeredgecolor='red', color='#A14189', linewidth=5)
# marker, markersize, markeredgecolor, markerfacecolor, linewidth, linestyle

# plt.xlabel('Numbers')
# plt.ylabel('Squares')
# Fontsize, Colour, Fontweight = 500/'bold'

# plt.xticks(range(1,11))
#rot

# plt.show()
